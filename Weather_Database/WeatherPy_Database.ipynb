# %% [markdown]
# Import Dependencies and Setup

# %%
# Import dependencies
import pandas as pd
import numpy as np
import requests
import time
import os
import json
import matplotlib.pyplot as plt
from datetime import datetime
from citipy import citipy

# Import API key
from config import weather_api_key

# Create output file
output_file = "/Users/anuoluwaposoniyi/Desktop/Class/Resources/Output/cities.csv"

# Range of latitude and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# Generate Cities List

# %%
# Create list to hold lat_lng, and cities
lat_lng = []
cities = []

# Create a new set of 2000 random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=2000)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=2000)
lat_lngs = zip(lats, lngs)

# Get the nearest city using the citipy module
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    

    # If city is not cities, then add it to the cities list
    if city not in cities:
        cities.append(city)   

# Print the cities count to verify sufficient count
len(cities)
# Out:
# 752

# %% [markdown]
# Perform an API call with the OpenWeatherMap

# %%
# Loop through the list of cities, and perform a request for data on each:
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial"
units = "imperial"
query_url = f"{url}&appid={weather_api_key}&units={units}&q="

# Initialize lists to hold results
lat = []
lon = []
max_temp = []
percent_humidity = []
percent_cloudiness = []
wind_speed = []
weather_desc = []
cities_found = []
countries = []

print("Begining Data Retrieval")
print("--------------------")

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        percent_humidity.append(response["main"]["humidity"])
        percent_cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        weather_desc.append(response["weather"][0]["description"])
        cities_found.append(city)
        countries.append(response["sys"]["country"])
        print(f"Processing Record: {city}")
        
    except:
        print("City not found. Skipping...")
print("---------------------")
print("Data Retrieval Complete")
print("---------------------")
# Out:
# Begining Data Retrieval
# --------------------
# Processing Record: busselton
# Processing Record: sampit
# Processing Record: bluff
# Processing Record: ushuaia
# City not found. Skipping...
# Processing Record: cherskiy
# Processing Record: wawa
# Processing Record: tuktoyaktuk
# Processing Record: ambunti
# Processing Record: upernavik
# Processing Record: los llanos de aridane
# Processing Record: vanavara
# Processing Record: ilulissat
# Processing Record: verkhnevilyuysk
# Processing Record: kalmunai
# Processing Record: najran
# Processing Record: pisco
# Processing Record: seoul
# City not found. Skipping...
# Processing Record: new norfolk
# Processing Record: cayenne
# Processing Record: victoria
# Processing Record: telsiai
# Processing Record: barrow
# Processing Record: san jeronimo
# Processing Record: rielasingen-worblingen
# Processing Record: faanui
# Processing Record: sobolevo
# Processing Record: punta arenas
# Processing Record: tarauaca
# Processing Record: north bend
# Processing Record: avarua
# Processing Record: nikolskoye
# Processing Record: severo-kurilsk
# Processing Record: iralaya
# Processing Record: vardo
# Processing Record: berlevag
# Processing Record: ahipara
# Processing Record: ust-ilimsk
# City not found. Skipping...
# Processing Record: feira de santana
# Processing Record: atuona
# Processing Record: port hardy
# Processing Record: naustdal
# Processing Record: volcan
# City not found. Skipping...
# Processing Record: husavik
# Processing Record: port elizabeth
# Processing Record: tazovskiy
# Processing Record: hithadhoo
# Processing Record: klaksvik
# Processing Record: buckeye
# Processing Record: bredasdorp
# Processing Record: vila velha
# Processing Record: hermanus
# Processing Record: katsuura
# Processing Record: vaini
# Processing Record: itaituba
# Processing Record: hobyo
# City not found. Skipping...
# Processing Record: moldoveni
# Processing Record: castro
# Processing Record: zavallya
# Processing Record: honiara
# Processing Record: vigrestad
# Processing Record: palmer
# Processing Record: mwene-ditu
# Processing Record: maniitsoq
# Processing Record: pemangkat
# Processing Record: havre-saint-pierre
# Processing Record: gimli
# Processing Record: srednekolymsk
# Processing Record: plettenberg bay
# Processing Record: burns lake
# Processing Record: yar-sale
# Processing Record: rikitea
# Processing Record: newport
# Processing Record: torrijos
# Processing Record: geraldton
# Processing Record: thompson
# Processing Record: mahebourg
# City not found. Skipping...
# Processing Record: bilma
# Processing Record: hobart
# Processing Record: auki
# Processing Record: washington
# City not found. Skipping...
# Processing Record: kapaa
# Processing Record: iqaluit
# Processing Record: jamestown
# Processing Record: wanning
# Processing Record: tasiilaq
# Processing Record: paciran
# City not found. Skipping...
# Processing Record: shelburne
# City not found. Skipping...
# Processing Record: taoudenni
# Processing Record: pevek
# City not found. Skipping...
# Processing Record: khatanga
# Processing Record: mehamn
# Processing Record: rio grande
# Processing Record: dikson
# Processing Record: mataura
# Processing Record: longyearbyen
# Processing Record: torbay
# Processing Record: kruisfontein
# Processing Record: qaanaaq
# Processing Record: chechat
# Processing Record: lovozero
# Processing Record: hovd
# Processing Record: dingle
# Processing Record: kahului
# Processing Record: puerto ayora
# Processing Record: olafsvik
# Processing Record: leshukonskoye
# Processing Record: veliko gradiste
# Processing Record: namie
# Processing Record: san patricio
# Processing Record: sao filipe
# Processing Record: hit
# Processing Record: korla
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: ayni
# Processing Record: kavieng
# Processing Record: huarmey
# Processing Record: bambous virieux
# Processing Record: gvardeysk
# Processing Record: silifke
# Processing Record: mar del plata
# Processing Record: provideniya
# Processing Record: lata
# Processing Record: la ronge
# Processing Record: boueni
# Processing Record: kalnciems
# Processing Record: salalah
# Processing Record: shingu
# Processing Record: fort walton beach
# Processing Record: college
# Processing Record: coahuayana
# Processing Record: coquimbo
# Processing Record: omsukchan
# Processing Record: port alfred
# Processing Record: richards bay
# City not found. Skipping...
# Processing Record: chuy
# Processing Record: faya
# City not found. Skipping...
# Processing Record: muisne
# Processing Record: zilina
# Processing Record: lompoc
# Processing Record: turukhansk
# Processing Record: yellowknife
# Processing Record: orlik
# Processing Record: hualmay
# Processing Record: constitucion
# Processing Record: sorland
# Processing Record: talnakh
# Processing Record: georgetown
# Processing Record: hami
# Processing Record: hauge
# Processing Record: cape town
# Processing Record: norman wells
# Processing Record: chokwe
# Processing Record: east london
# Processing Record: izumo
# Processing Record: egvekinot
# Processing Record: banepa
# Processing Record: karakulino
# Processing Record: saldanha
# Processing Record: cadereyta
# Processing Record: kangaatsiaq
# Processing Record: alofi
# Processing Record: carlos chagas
# Processing Record: guerrero negro
# City not found. Skipping...
# Processing Record: bethel
# Processing Record: yulara
# Processing Record: itoman
# Processing Record: lebu
# Processing Record: mukhen
# Processing Record: broome
# Processing Record: cabedelo
# Processing Record: mount gambier
# Processing Record: charters towers
# Processing Record: nampula
# City not found. Skipping...
# Processing Record: cidreira
# Processing Record: kaitangata
# Processing Record: cabo san lucas
# Processing Record: leningradskiy
# Processing Record: angoram
# Processing Record: zafra
# Processing Record: sakakah
# Processing Record: niono
# Processing Record: soderhamn
# Processing Record: burnie
# Processing Record: saskylakh
# Processing Record: vila do maio
# City not found. Skipping...
# Processing Record: airai
# Processing Record: los negros
# City not found. Skipping...
# Processing Record: isangel
# Processing Record: lindi
# Processing Record: bisira
# Processing Record: okhotsk
# Processing Record: montrose
# Processing Record: mugango
# Processing Record: hamilton
# Processing Record: chokurdakh
# Processing Record: barcelos
# City not found. Skipping...
# Processing Record: bubaque
# Processing Record: albany
# Processing Record: haimen
# Processing Record: le port
# Processing Record: jennings
# Processing Record: arraial do cabo
# City not found. Skipping...
# Processing Record: mizdah
# Processing Record: caravelas
# Processing Record: broken hill
# Processing Record: mitsamiouli
# Processing Record: ponta do sol
# Processing Record: dunedin
# Processing Record: joshimath
# Processing Record: hasaki
# Processing Record: fort nelson
# Processing Record: kodiak
# City not found. Skipping...
# Processing Record: sola
# City not found. Skipping...
# Processing Record: bassila
# Processing Record: alice springs
# Processing Record: hofn
# Processing Record: mandurah
# City not found. Skipping...
# Processing Record: bafoulabe
# Processing Record: yankton
# Processing Record: chulym
# Processing Record: vila franca do campo
# Processing Record: lensk
# Processing Record: okato
# Processing Record: mahon
# Processing Record: petropavlovsk-kamchatskiy
# Processing Record: atambua
# Processing Record: road town
# Processing Record: kaeo
# Processing Record: marsa matruh
# Processing Record: boende
# Processing Record: grand gaube
# Processing Record: carnarvon
# Processing Record: bakchar
# Processing Record: buchanan
# Processing Record: namatanai
# Processing Record: les cayes
# Processing Record: matagami
# Processing Record: yatou
# Processing Record: ponta delgada
# Processing Record: svetlogorsk
# Processing Record: linxia
# Processing Record: abrau-dyurso
# Processing Record: comodoro rivadavia
# Processing Record: ancud
# Processing Record: port-cartier
# City not found. Skipping...
# Processing Record: nelson bay
# Processing Record: batemans bay
# Processing Record: tura
# Processing Record: konosha
# Processing Record: lesnoy
# Processing Record: kutum
# Processing Record: cururupu
# Processing Record: yuanping
# Processing Record: yenotayevka
# Processing Record: manzanillo
# Processing Record: atar
# Processing Record: babusnica
# Processing Record: aklavik
# Processing Record: sayyan
# Processing Record: kavaratti
# Processing Record: horta
# Processing Record: salamiyah
# Processing Record: porbandar
# Processing Record: oistins
# Processing Record: oda
# Processing Record: pampierstad
# Processing Record: saint-philippe
# Processing Record: ojinaga
# Processing Record: hlotse
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: aksarka
# Processing Record: muros
# Processing Record: west wendover
# Processing Record: thunder bay
# Processing Record: kununurra
# Processing Record: barreiras
# Processing Record: hilo
# Processing Record: gelemso
# Processing Record: shenjiamen
# Processing Record: port macquarie
# City not found. Skipping...
# Processing Record: clyde river
# Processing Record: kalmar
# Processing Record: rio gallegos
# Processing Record: requena
# Processing Record: tadine
# Processing Record: yerbogachen
# Processing Record: dawlatabad
# Processing Record: isabela
# Processing Record: manta
# Processing Record: khani
# Processing Record: maceio
# Processing Record: meulaboh
# Processing Record: vestmanna
# City not found. Skipping...
# Processing Record: ribeira grande
# Processing Record: nova prata
# Processing Record: bouna
# Processing Record: kutina
# Processing Record: fethiye
# Processing Record: mogadishu
# Processing Record: matongo
# Processing Record: sitka
# Processing Record: port-gentil
# Processing Record: chiang klang
# Processing Record: pangoa
# Processing Record: muzhi
# Processing Record: codrington
# Processing Record: snasa
# Processing Record: abha
# Processing Record: ifakara
# Processing Record: zinacantan
# City not found. Skipping...
# Processing Record: bathsheba
# City not found. Skipping...
# Processing Record: tiksi
# Processing Record: kaya
# Processing Record: ballina
# Processing Record: fort frances
# Processing Record: fushun
# Processing Record: butaritari
# Processing Record: lagoa
# Processing Record: beringovskiy
# Processing Record: novouzensk
# Processing Record: lavrentiya
# Processing Record: cameta
# Processing Record: port keats
# Processing Record: clarence town
# Processing Record: lianran
# Processing Record: merrill
# City not found. Skipping...
# Processing Record: north vanlaiphai
# Processing Record: sistranda
# Processing Record: fortuna
# Processing Record: komsomolskiy
# Processing Record: trairi
# Processing Record: maracas
# Processing Record: coos bay
# Processing Record: huangchuan
# Processing Record: talaya
# Processing Record: teguise
# Processing Record: ostrovnoy
# Processing Record: santa marta
# Processing Record: berdigestyakh
# Processing Record: maragogi
# Processing Record: kralendijk
# City not found. Skipping...
# Processing Record: cartagena
# Processing Record: quatre cocos
# Processing Record: nalut
# Processing Record: oranjemund
# Processing Record: marquette
# Processing Record: mount isa
# Processing Record: vestmannaeyjar
# Processing Record: lhokseumawe
# Processing Record: esmeraldas
# Processing Record: nome
# Processing Record: tigil
# Processing Record: parfino
# Processing Record: nizhniy baskunchak
# Processing Record: panama city
# City not found. Skipping...
# Processing Record: chacabuco
# Processing Record: nueva loja
# Processing Record: sept-iles
# Processing Record: svetlaya
# Processing Record: nyurba
# Processing Record: santo antonio do ica
# Processing Record: zhezkazgan
# Processing Record: baykit
# City not found. Skipping...
# Processing Record: pangody
# City not found. Skipping...
# Processing Record: tilichiki
# Processing Record: zabol
# Processing Record: portland
# Processing Record: praia da vitoria
# Processing Record: touros
# Processing Record: lang suan
# Processing Record: ust-ordynskiy
# Processing Record: ulaangom
# Processing Record: dargaville
# Processing Record: balabac
# Processing Record: aljezur
# Processing Record: takoradi
# Processing Record: sorong
# Processing Record: khandyga
# Processing Record: alta floresta
# Processing Record: taltal
# Processing Record: flinders
# Processing Record: honningsvag
# Processing Record: arandis
# Processing Record: rach gia
# Processing Record: yerofey pavlovich
# Processing Record: sosua
# Processing Record: adrar
# Processing Record: el higo
# Processing Record: lorengau
# Processing Record: ust-nera
# Processing Record: lasa
# Processing Record: esperance
# Processing Record: woodward
# Processing Record: krasnoselkup
# Processing Record: tablas
# Processing Record: souillac
# Processing Record: codo
# Processing Record: baley
# Processing Record: angatuba
# Processing Record: ternate
# Processing Record: gallup
# Processing Record: henties bay
# Processing Record: cayeli
# Processing Record: dwarka
# Processing Record: mindelo
# Processing Record: qasigiannguit
# Processing Record: hare bay
# Processing Record: deputatskiy
# Processing Record: long beach
# Processing Record: aykhal
# Processing Record: avera
# Processing Record: tiznit
# Processing Record: shimanovsk
# Processing Record: karratha
# Processing Record: kamina
# Processing Record: dubai
# Processing Record: izmaylovo
# Processing Record: muli
# Processing Record: luba
# Processing Record: sao joao da barra
# Processing Record: general roca
# City not found. Skipping...
# Processing Record: samdrup jongkhar
# Processing Record: marystown
# Processing Record: ler
# Processing Record: san quintin
# Processing Record: sambava
# Processing Record: zenzeli
# Processing Record: along
# Processing Record: ucluelet
# Processing Record: jasper
# Processing Record: dengzhou
# Processing Record: leon valley
# Processing Record: jhinjhana
# Processing Record: balkanabat
# Processing Record: sabang
# Processing Record: kasongo
# Processing Record: kanniyakumari
# Processing Record: tamiahua
# Processing Record: poum
# Processing Record: westport
# Processing Record: haines junction
# Processing Record: karachi
# Processing Record: santiago del estero
# Processing Record: port blair
# Processing Record: glasgow
# Processing Record: tsiroanomandidy
# Processing Record: shitkino
# Processing Record: erzin
# Processing Record: camopi
# Processing Record: nioro
# Processing Record: jalu
# Processing Record: viedma
# Processing Record: verkhnyaya toyma
# Processing Record: bengkulu
# Processing Record: wamba
# Processing Record: luderitz
# Processing Record: turkistan
# Processing Record: san matias
# Processing Record: naze
# Processing Record: galle
# Processing Record: afua
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: sandpoint
# Processing Record: bud
# Processing Record: riyadh
# Processing Record: pinega
# Processing Record: christchurch
# Processing Record: lexington park
# Processing Record: sao jose da coroa grande
# Processing Record: kargasok
# Processing Record: lethem
# Processing Record: zhigansk
# Processing Record: raymond
# Processing Record: puksoozero
# Processing Record: nemuro
# Processing Record: san vicente
# Processing Record: lahaina
# Processing Record: lat yao
# Processing Record: bourail
# Processing Record: ilhabela
# Processing Record: saint-augustin
# Processing Record: hay river
# Processing Record: tual
# Processing Record: wewak
# Processing Record: tungor
# Processing Record: soyo
# Processing Record: barentu
# Processing Record: leopoldshohe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: viterbo
# Processing Record: ardakan
# Processing Record: moose factory
# Processing Record: labuhan
# Processing Record: valley station
# Processing Record: svetlyy
# Processing Record: tevriz
# Processing Record: paragominas
# Processing Record: luanshya
# Processing Record: sokoni
# Processing Record: gradacac
# Processing Record: balaghat
# Processing Record: mayo
# Processing Record: roald
# Processing Record: fredericton
# Processing Record: jiuquan
# Processing Record: campina verde
# Processing Record: mabaruma
# Processing Record: longkou
# Processing Record: bardiyah
# Processing Record: jutai
# Processing Record: talcahuano
# Processing Record: trelew
# Processing Record: ibimirim
# Processing Record: mazara del vallo
# Processing Record: cuenca
# Processing Record: tautira
# Processing Record: reconquista
# Processing Record: akdepe
# Processing Record: rocha
# Processing Record: quezaltepeque
# Processing Record: waddan
# Processing Record: williams lake
# Processing Record: camacha
# Processing Record: milkovo
# Processing Record: eidsvag
# Processing Record: shakhtinsk
# Processing Record: belmonte
# Processing Record: waingapu
# Processing Record: villazon
# Processing Record: san rafael
# Processing Record: sehithwa
# Processing Record: tevaitoa
# Processing Record: leon
# Processing Record: tiarei
# Processing Record: samagaltay
# Processing Record: semey
# Processing Record: beihai
# Processing Record: semporna
# Processing Record: chapais
# Processing Record: kenai
# Processing Record: abu samrah
# Processing Record: whitehorse
# Processing Record: funadhoo
# Processing Record: port huron
# Processing Record: skoczow
# Processing Record: cleburne
# Processing Record: lafiagi
# Processing Record: jamame
# Processing Record: suntar
# Processing Record: san andres
# Processing Record: oussouye
# Processing Record: birin
# Processing Record: zhuravka
# Processing Record: pinheiro machado
# Processing Record: beisfjord
# Processing Record: kungurtug
# Processing Record: krasnoborsk
# Processing Record: razdolinsk
# Processing Record: burdur
# Processing Record: zambezi
# Processing Record: ust-maya
# Processing Record: gamba
# Processing Record: kalianget
# Processing Record: zalantun
# Processing Record: samarai
# Processing Record: norfolk
# City not found. Skipping...
# Processing Record: chumikan
# Processing Record: arys
# Processing Record: biloxi
# Processing Record: nantucket
# City not found. Skipping...
# Processing Record: lamar
# City not found. Skipping...
# Processing Record: eureka
# Processing Record: clones
# City not found. Skipping...
# Processing Record: coruripe
# City not found. Skipping...
# Processing Record: majene
# Processing Record: port lincoln
# City not found. Skipping...
# Processing Record: mayumba
# Processing Record: monte alegre
# Processing Record: valparaiso
# City not found. Skipping...
# Processing Record: dali
# Processing Record: pivijay
# Processing Record: waipawa
# Processing Record: noumea
# Processing Record: anadyr
# Processing Record: hambantota
# Processing Record: vanimo
# Processing Record: ratnagiri
# Processing Record: langholm
# Processing Record: naryan-mar
# City not found. Skipping...
# Processing Record: isla mujeres
# Processing Record: le vauclin
# Processing Record: prince george
# Processing Record: olinda
# Processing Record: nurota
# Processing Record: alyangula
# Processing Record: agadir
# Processing Record: bennettsville
# Processing Record: qiqihar
# Processing Record: porto torres
# City not found. Skipping...
# Processing Record: salinopolis
# Processing Record: kurilsk
# Processing Record: yaring
# Processing Record: aberdeen
# Processing Record: saint-pierre
# Processing Record: bonthe
# Processing Record: pelotas
# Processing Record: ovsyanka
# City not found. Skipping...
# Processing Record: hulyaypole
# Processing Record: victoria point
# Processing Record: pangkalanbuun
# Processing Record: la libertad
# Processing Record: omboue
# Processing Record: grindavik
# Processing Record: green river
# Processing Record: port moresby
# Processing Record: saint george
# Processing Record: biak
# Processing Record: half moon bay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: paijan
# Processing Record: baturaja
# Processing Record: tuatapere
# Processing Record: mujiayingzi
# City not found. Skipping...
# Processing Record: izhma
# Processing Record: scottsbluff
# Processing Record: forssa
# Processing Record: ixtapa
# Processing Record: narsaq
# Processing Record: ipswich
# Processing Record: sungaipenuh
# Processing Record: tianpeng
# Processing Record: guiren
# Processing Record: faranah
# Processing Record: kodoli
# Processing Record: maraa
# Processing Record: puerto carreno
# Processing Record: uyovu
# Processing Record: lisakovsk
# Processing Record: akureyri
# Processing Record: damaturu
# Processing Record: boa vista
# Processing Record: aksu
# Processing Record: borogontsy
# Processing Record: vagur
# Processing Record: blackfoot
# Processing Record: catamarca
# Processing Record: foso
# Processing Record: mandalgovi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: keita
# Processing Record: udachnyy
# Processing Record: channel-port aux basques
# City not found. Skipping...
# Processing Record: arlit
# Processing Record: minot
# Processing Record: senneterre
# Processing Record: davila
# City not found. Skipping...
# Processing Record: sawakin
# City not found. Skipping...
# City not found. Skipping...
# Processing Record: brownsville
# Processing Record: kochevo
# Processing Record: borovoy
# Processing Record: inyonga
# Processing Record: kerema
# Processing Record: bell ville
# Processing Record: tunceli
# Processing Record: puerto lumbreras
# Processing Record: manokwari
# Processing Record: batagay
# Processing Record: yaviza
# Processing Record: narwana
# Processing Record: daru
# Processing Record: sao gabriel da cachoeira
# Processing Record: jiaonan
# Processing Record: exeter
# Processing Record: baghdad
# City not found. Skipping...
# Processing Record: laguna
# Processing Record: pagudpud
# Processing Record: san ramon
# Processing Record: neiafu
# Processing Record: port hedland
# Processing Record: assiniboia
# Processing Record: odweyne
# Processing Record: le pradet
# Processing Record: kuantan
# Processing Record: pokhara
# Processing Record: manggar
# Processing Record: ales
# Processing Record: merauke
# Processing Record: wajima
# Processing Record: dipalpur
# Processing Record: cedar city
# Processing Record: juegang
# City not found. Skipping...
# Processing Record: fairbanks
# Processing Record: nirmali
# Processing Record: mesagne
# Processing Record: gat
# Processing Record: ban nahin
# Processing Record: ilo
# ---------------------
# Data Retrieval Complete
# ---------------------

# %% [markdown]
# Convert results to a dataframe
# Display the dataframe
# Export into a CSV file

# %%
# Convert into a dataframe
weather_df = pd.DataFrame({
    "City" : cities_found,
    "Country" : countries,
    "Lat": lat,
    "Lon" : lon,
    "Max Temp" : max_temp,
    "Humidity" : percent_humidity,
    "Cloudiness" : percent_cloudiness,
    "Current Description" : weather_desc
    })
weather_df
# Out:
#           City Country      Lat       Lon  Max Temp  Humidity  Cloudiness  \
# 0    busselton      AU -33.6500  115.3333     57.20        66          85
# 1       sampit      ID  -2.5333  112.9500     75.47        90          90
# 2        bluff      NZ -46.6000  168.3333     46.62        85           6
# 3      ushuaia      AR -54.8000  -68.3000     51.46        71          75
# 4     cherskiy      RU  68.7500  161.3000      6.48        94         100
# ..         ...     ...      ...       ...       ...       ...         ...
# 686    nirmali      IN  26.3167   86.5833     78.58        65           0
# 687    mesagne      IT  40.5588   17.8083     56.44        62          20
# 688        gat      IL  31.6100   34.7642     86.68        24           8
# 689  ban nahin      LA  18.2418  104.2122     72.30        91          98
# 690        ilo      PE -17.6394  -71.3375     68.05        72          84
#
#     Current Description
# 0       overcast clouds
# 1       overcast clouds
# 2             clear sky
# 3         broken clouds
# 4       overcast clouds
# ..                  ...
# 686           clear sky
# 687          few clouds
# 688           clear sky
# 689     overcast clouds
# 690       broken clouds
#
# [691 rows x 8 columns]

# %%
# Save city data into a csv file
weather_df.to_csv("/Users/anuoluwaposoniyi/Desktop/Class/Resources/Output/WeatherPy_Database.csv")
